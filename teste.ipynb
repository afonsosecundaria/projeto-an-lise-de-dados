# %%
# !pip install pandas
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
tabela_final = pd.DataFrame( columns=['Nome', 'Curso', 'Status_Curso'])

# %%
tabela_sisu_2020_2 = pd.read_csv('basesdedados/ListagemChamadaRegular_2020-2.csv', sep=';')
tabela_sisu_2020_2.head()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_16392\3214906904.py:1: DtypeWarning: Columns (19,20,21,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   tabela_sisu_2020_2 = pd.read_csv('basesdedados/ListagemChamadaRegular_2020-2.csv', sep=';')
#    NU_ANO  NU_EDICAO  CO_ETAPA    DS_ETAPA  CO_IES  \
# 0    2020          2         4  1° CHAMADA     688
# 1    2020          2         4  1° CHAMADA     688
# 2    2020          2         4  1° CHAMADA     688
# 3    2020          2         4  1° CHAMADA     688
# 4    2020          2         4  1° CHAMADA     688
#
#                                        NO_IES SIGLA_IES SG_UF_IES  CO_CAMPUS  \
# 0  UNIVERSIDADE ESTADUAL DO SUDOESTE DA BAHIA      UESB        BA        301
# 1  UNIVERSIDADE ESTADUAL DO SUDOESTE DA BAHIA      UESB        BA        301
# 2  UNIVERSIDADE ESTADUAL DO SUDOESTE DA BAHIA      UESB        BA        301
# 3  UNIVERSIDADE ESTADUAL DO SUDOESTE DA BAHIA      UESB        BA        301
# ...

# %%
nome_view = tabela_sisu_2020_2['NO_INSCRITO']
nome_view
# Out:
# 0                   BIANCA STEPHANE DA SILVA
# 1                  DYANA MENDES GOMES SANTOS
# 2                  ISADORA SANTIAGO FERREIRA
# 3          LARA ESTHER MENDES SILVA OLIVEIRA
# 4                  NAIARA PEREIRA DOS SANTOS
#                          ...
# 814471         IANKA ANALIA BOTELHO DE SOUZA
# 814472     VINICCIUS MARQUES FERNANDES MOZER
# 814473             MARIANA MIBIELLI DE SOUZA
# 814474    MONYKE GABRIELLY FERREIRA FERREIRA
# 814475           LIVIA BRUNA DE ANDRADE DO O
# Name: NO_INSCRITO, Length: 814476, dtype: object

# %%
for i in range(40):
    tabela_final.loc[len(tabela_final)] = {
        'Nome': nome_view[i],
        'Curso' : 'Ainda nada',
        'Status_Curso': 'Cursando'
    }
display(tabela_final)
# Out:
#                                  Nome       Curso Status_Curso
# 0            BIANCA STEPHANE DA SILVA  Ainda nada     Cursando
# 1           DYANA MENDES GOMES SANTOS  Ainda nada     Cursando
# 2           ISADORA SANTIAGO FERREIRA  Ainda nada     Cursando
# 3   LARA ESTHER MENDES SILVA OLIVEIRA  Ainda nada     Cursando
# 4           NAIARA PEREIRA DOS SANTOS  Ainda nada     Cursando
# 5                 GISELE BRITO SANTOS  Ainda nada     Cursando
# 6             SUZANA DE OLIVEIRA DIAS  Ainda nada     Cursando
# 7      VITORIA DO NASCIMENTO OLIVEIRA  Ainda nada     Cursando
# 8            ELIVANIA BASTOS OLIVEIRA  Ainda nada     Cursando
# 9             IAN VICTTOR SOUZA SILVA  Ainda nada     Cursando
# 10                ANGELA ASSIS VIEIRA  Ainda nada     Cursando
# 11        ROSANGELA SOUZA DE OLIVEIRA  Ainda nada     Cursando
# 12                DANIELLE DOS SANTOS  Ainda nada     Cursando
# 13   NATIELE SOUZA OLIVEIRA DE ARAGAO  Ainda nada     Cursando
# ...

# %%
# Criando uma tabela de teste com nomes que estão na base e outros que não estão
